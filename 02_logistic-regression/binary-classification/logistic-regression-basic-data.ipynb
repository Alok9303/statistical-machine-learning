# %%
import pandas as pd
df = pd.read_csv('insurance_data.csv')

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
import matplotlib.pyplot as plt
plt.scatter(df.age,df.bought_insurance, color = 'red', marker = '+')
plt.xlabel('Binary Classification(Yes/No)', color = 'blue')
# Out:
# Text(0.5, 0, 'Binary Classification(Yes/No)')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df['bought_insurance'],test_size = 0.2)

# %%
from sklearn.linear_model  import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 11   28
# 26   23
# 4    46
# 3    52
# 13   29
# 21   26

# %%
model.predict(X_test)
# Out:
# array([0, 0, 1, 1, 0, 0])

# %%
model.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
model.predict_proba(X_test)
# Out:
# array([[0.7176936 , 0.2823064 ],
#        [0.83659459, 0.16340541],
#        [0.16978521, 0.83021479],
#        [0.08112067, 0.91887933],
#        [0.68848341, 0.31151659],
#        [0.77084205, 0.22915795]])

# %% [markdown]
#     Increased the train_size(not recommended)

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df['bought_insurance'],test_size = 0.1)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 17   58
# 4    46
# 19   18

# %%
model.predict(X_test)
# Out:
# array([1, 1, 0])

# %%
model.score(X_test,y_test)
# Out:
# 1.0
