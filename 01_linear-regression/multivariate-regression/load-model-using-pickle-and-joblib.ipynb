# %%
import pickle
import joblib

# %% [markdown]
#      Find the Salary of the candidate With 2 years experiance, 9 Test Score, 6 Interview Score

# %%
with open("model_pickle","rb") as f:
    salary_model = pickle.load(f)

# %%
salary_model.predict([[2,9,6]])
# Out:
# C:\Users\alokk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53205.96797671])

# %% [markdown]
#     Predict the Price of the Home that has Area=3000 sqft, Bedrooms=3, age=30 years old

# %%
price_model = joblib.load("model_joblib")

# %%
price_model.predict([[3000,3,30]])
# Out:
# C:\Users\alokk\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([530725.43066664])
